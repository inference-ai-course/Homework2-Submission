# %%
# test libraries we intend to use.
import pytesseract as pt
from PIL import Image as img

print(pt.get_languages(config=''))
# Out:
# ['eng', 'osd', 'snum']

# %%
image = f"test/images-with-text/py-tesseract-screenshot.png"
img.open(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1140>

# %%
try:
    text_in_img = pt.image_to_string(image )
    print(f"Converted text\n{text_in_img}")
except Exception as e:
    print(f"There was a problem: {e}")
# Out:
# Converted text
# faze madmaze
#
# Unverified details
# These details have not been verified by PyPl
#
# Project links
#
# ff Homepage
#
# Meta
#
# © License: Apache Software License
# (Apache License 2.0)
#
# Author: Samuel Hoffstaetter@
# Maintainer: Matthias Lee@
#
# ® python-tesseract , OCR , Python
# Requires: Python >=3.8
#
# Classifiers
#
# License
# © OSI! Approved
# License
#
# pache Software
#
# Programming Language
#
# + Ask Gemini? x
#
# Take the survey now
#
# USAGE
#
# Quickstart
# Note: Test images are located in the tests/data folder of the Git repo.
#
# Library usage:
#
# from PIL import Image
# ‘import pytesseract
#
# # If you don't have tesseract executable in your PATH, include the following:
# pytesseract.pytesseract.tesseract_cmd = r'<full_path_to_your_tesseract_executable>!
# # Example tesseract_cmd = r'C:\Program Files (x86) \Tesseract-OCR\tesseract!
#
# # Simple image to string
# print (pytesseract. image_to_string(Image.open('test.png')))
#
# ...

# %%
# text postprocessing
# Out:
# <class 'str'>
# es

# %%
# lets test example 2
research_paper = f"test/images-with-text/paper.png"

research_paper_text = pt.image_to_string(image=img.open(research_paper))
bounding_boxes = pt.image_to_boxes(image=img.open(research_paper))
print(research_paper_text)
print(f"Bounding Boxes: {bounding_boxes}")
# Out:
# Boosting the cosmic 21-cm signal with exotic Lyman-a from dark matter
#
# Dominic Agius"
# Instituto de Fisica Corpuscular (IFIC), CSIC-Universitat de Valencia, Valencia 46071, Spain
#
# ‘Tracy R. Slatyert
# MIT Center for Theoretical Physics - a Leinweber Institute,
# Massachusetts Institute of Technology, Cambridge, Massachusetts 02139, U.S.A
# (Dated: October $1, 2025)
#
# ‘The 2l-cm signal from the epoch of cosmnie dawn (= ~ 10-30) offers a powerful probe of new
# physics. One standard mechanism for constraining decaying dark matter from 21-cm observations
# ‘relies on heating of the intergalactic medium by the decay products, an effect whose observability is
# entangled with the uncertain Lyman-a fuxes and X-ray heating from the first stars. In this Letter,
# ‘we explore a novel mechanism, where the Lyman-a photons produced from dark matter decay init
# cearly Wouthuysen Field coupling of the spin temperature to the gas temperature, thereby boosting
# ...
