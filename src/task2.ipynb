# %%
import os

# find the pdfs for the papers
pdf_dir = "utils/test/pdfs/arxiv/0"

file_list = os.listdir(pdf_dir)

if len(file_list) < 0:
    ...
else:
    ...

pdf_files = [ f for f in file_list if os.path.isfile(os.path.join(pdf_dir, f)) and f.endswith(".pdf") ]

full_pdf_paths = [ os.path.join(pdf_dir, f) for f in pdf_files ]
full_pdf_paths
# Out:
# ['utils/test/pdfs/arxiv/0/2406.03470.pdf',
#  'utils/test/pdfs/arxiv/0/2510.20795.pdf',
#  'utils/test/pdfs/arxiv/0/2509.06383.pdf',
#  'utils/test/pdfs/arxiv/0/2503.05840.pdf',
#  'utils/test/pdfs/arxiv/0/2505.07222.pdf',
#  'utils/test/pdfs/arxiv/0/2412.20875.pdf',
#  'utils/test/pdfs/arxiv/0/2505.09651.pdf',
#  'utils/test/pdfs/arxiv/0/2306.01926.pdf',
#  'utils/test/pdfs/arxiv/0/2508.18155.pdf',
#  'utils/test/pdfs/arxiv/0/2307.12775.pdf',
#  'utils/test/pdfs/arxiv/0/2304.04556.pdf',
#  'utils/test/pdfs/arxiv/0/2508.13874.pdf',
#  'utils/test/pdfs/arxiv/0/2407.01375.pdf',
#  'utils/test/pdfs/arxiv/0/2506.21063.pdf',
#  'utils/test/pdfs/arxiv/0/2507.03014.pdf',
#  'utils/test/pdfs/arxiv/0/2410.00907.pdf',
#  'utils/test/pdfs/arxiv/0/2104.04692.pdf',
#  'utils/test/pdfs/arxiv/0/2304.06212.pdf',
#  'utils/test/pdfs/arxiv/0/2401.11143.pdf',
#  'utils/test/pdfs/arxiv/0/2109.07043.pdf',
#  'utils/test/pdfs/arxiv/0/2103.03404.pdf',
#  'utils/test/pdfs/arxiv/0/2501.06929.pdf',
# ...

# %%
pdf_to_image_path = os.makedirs(os.path.join(pdf_dir, "images"), exist_ok=True)

# %%
import utils.pdf_ocr_extractor as extractor

extractor.extract_text_from_pdf("utils/test/pdfs/arxiv/0/2510.03565.pdf")
# Out:
# 2025-11-01 07:21:33,155 - DEBUG - ['tesseract', '/tmp/tess_fzti19yu_input.PPM', '/tmp/tess_fzti19yu', 'txt']
# 2025-11-01 07:21:47,260 - DEBUG - ['tesseract', '/tmp/tess_12vo7rxn_input.PPM', '/tmp/tess_12vo7rxn', 'txt']
# 2025-11-01 07:22:04,542 - DEBUG - ['tesseract', '/tmp/tess_stb80e1w_input.PPM', '/tmp/tess_stb80e1w', 'txt']
# 2025-11-01 07:22:24,538 - DEBUG - ['tesseract', '/tmp/tess_6c6_chbr_input.PPM', '/tmp/tess_6c6_chbr', 'txt']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 import utils.pdf_ocr_extractor as extractor
# ----> 3 extractor.extract_text_from_pdf("utils/test/pdfs/arxiv/0/2510.03565.pdf")
#
# File /mnt/blockvolume/ai-engineer/submissions/Homework2-Submission/src/utils/pdf_ocr_extractor.py:16, in extract_text_from_pdf(pdf_path, dpi)
#      14 text = ""
#      15 for page in pages:
# ...
