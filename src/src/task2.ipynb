# %%
import os
import utils.pdf_ocr_extractor as extractor

script_dir = os.path.dirname(os.path.abspath("__file__"))
pdf_dir = os.path.join(script_dir, "arxiv_pdfs/")
output_dir = os.path.join(script_dir, "pdf_ocr/")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

pdf_files = [f for f in os.listdir(pdf_dir) if f.endswith(".pdf")]

for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_dir, pdf_file)
    try:
        text = extractor.extract_text_from_pdf(pdf_path)
        output_filename = os.path.splitext(pdf_file)[0] + ".txt"
        output_path = os.path.join(output_dir, output_filename)
        with open(output_path, "w", encoding="utf-8") as f:
            f.write(text)
        print(f"Successfully processed {pdf_file}")
    except Exception as e:
        print(f"Error processing {pdf_file}: {e}")
# Out:
# 2025-11-04 12:38:01,333 - DEBUG - Number of pages: [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2481x3508 at 0x7B2A1D194C90>]
# 2025-11-04 12:38:01,373 - DEBUG - ['tesseract', '/tmp/tess_ks5_f4bm_input.JPEG', '/tmp/tess_ks5_f4bm', '-l', 'eng', 'txt']
# Successfully processed 2510.26641.pdf
